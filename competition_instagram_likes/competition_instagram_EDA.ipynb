# %% [markdown]
# ## Instagram data EDA
# ## **TEAM D-TALE**
# **SYMBIOSIS INSTITUTE OF OPERATIONS MANAGEMENT, NASHIK**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.simplefilter('ignore')

# %%
train = pd.read_csv('C://Users//Anuvrat Shukla//Desktop//competitions//Analytics//Regression//ISB _Intagram posts//train.csv',encoding="ISO-8859-1", parse_dates=[10,11])
train.shape
# Out:
# (16539, 22)

# %%
train.columns
# Out:
# Index(['numberPosts', 'Website', 'urlProfile', 'username', 'numberFollowing',
#        'descriptionProfile', 'alias', 'numberFollowers', 'urlImgProfile',
#        'filename', 'Date', 'urlImage', 'mentions', 'multipleImage',
#        'NoOfImages', 'isVideo', 'localization', 'tags', 'numberLikes', 'url',
#        'Influencer Level', 'description'],
#       dtype='object')

# %%
train.head()
# Out:
#    numberPosts                           Website  \
# 0           49  instagram.com/bestofstreetstyled
# 1           49  instagram.com/bestofstreetstyled
# 2           49  instagram.com/bestofstreetstyled
# 3           49  instagram.com/bestofstreetstyled
# 4           49  instagram.com/bestofstreetstyled
#
#                              urlProfile                       username  \
# 0  https://www.instagram.com/mensflair/  Men | Style | Class | Fashion
# 1  https://www.instagram.com/mensflair/  Men | Style | Class | Fashion
# 2  https://www.instagram.com/mensflair/  Men | Style | Class | Fashion
# 3  https://www.instagram.com/mensflair/  Men | Style | Class | Fashion
# 4  https://www.instagram.com/mensflair/  Men | Style | Class | Fashion
#
#    numberFollowing                                 descriptionProfile  \
# 0               10  Menswear & Lifestyle BE INSPIRED DAILY ____ Fo...
# 1               10  Menswear & Lifestyle BE INSPIRED DAILY ____ Fo...
# 2               10  Menswear & Lifestyle BE INSPIRED DAILY ____ Fo...
# 3               10  Menswear & Lifestyle BE INSPIRED DAILY ____ Fo...
# 4               10  Menswear & Lifestyle BE INSPIRED DAILY ____ Fo...
#
#        alias  numberFollowers  \
# 0  mensflair           124965
# 1  mensflair           124965
# 2  mensflair           124965
# 3  mensflair           124965
# 4  mensflair           124965
#
#                                        urlImgProfile  \
# 0  https://scontent.cdninstagram.com/t51.2885-19/...
# 1  https://scontent.cdninstagram.com/t51.2885-19/...
# 2  https://scontent.cdninstagram.com/t51.2885-19/...
# 3  https://scontent.cdninstagram.com/t51.2885-19/...
# 4  https://scontent.cdninstagram.com/t51.2885-19/...
#
#                                             filename  ...           mentions  \
# 0  18161447_1658356384474317_9111601070664056832_...  ...     ['@the_vasco']
# 1  18298601_121409661745614_6986690297598050304_n...  ...  ['@johnnyedlind']
# 2  18161743_412774429107168_768065153252982784_n.jpg  ...      ['@max_haim']
# 3  18251869_290881328035320_2327183756814712832_n...  ...     ['@magic_fox']
# 4  18160659_214392992395434_3720859060493352960_n...  ...      ['@bookonin']
#
#   multipleImage NoOfImages  isVideo  localization  \
# 0             0          1        0           NaN
# 1             0          1        0           NaN
# 2             0          1        0           NaN
# 3             0          1        0           NaN
# 4             0          1        0           NaN
#
#                                                 tags numberLikes  \
# 0  ['#suit', '#suits', '#gentlemen', '#gentlemens...          17
# 1                                                 []         304
# 2                                                 []         438
# 3  ['#suit', '#suits', '#gentlemen', '#gentlemens...         272
# 4                                                 []         672
#
#                                                  url  Influencer Level  \
# 0  https://www.instagram.com/p/BTilZcThQq5/?taken...    Low Influencer
# 1  https://www.instagram.com/p/BTiROoghcLV/?taken...    Low Influencer
# 2  https://www.instagram.com/p/BTh66MZB7BP/?taken...    Low Influencer
# 3  https://www.instagram.com/p/BThniHNlXhO/?taken...    Low Influencer
# 4  https://www.instagram.com/p/BThRe9-BZh0/?taken...    Low Influencer
#
#                                          description
# 0  Courtesy of @the_vasco\r\n____________________...
# 1  Style by: @johnnyedlind\r\nWhatcha say ï¿½ï¿½ï...
# 2  Stunning View - Tag Someone You Would Skydive ...
# 3  Courtesy of @magic_fox\r\n____________________...
# 4  Tag someone you would take - Santorini, Greece...
#
# [5 rows x 22 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16539 entries, 0 to 16538
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   numberPosts         16539 non-null  int64
#  1   Website             14652 non-null  object
#  2   urlProfile          16539 non-null  object
#  3   username            16335 non-null  object
#  4   numberFollowing     16539 non-null  int64
#  5   descriptionProfile  16148 non-null  object
#  6   alias               16539 non-null  object
#  7   numberFollowers     16539 non-null  int64
#  8   urlImgProfile       16539 non-null  object
#  9   filename            16539 non-null  object
#  10  Date                16539 non-null  datetime64[ns]
#  11  urlImage            16539 non-null  object
#  12  mentions            16539 non-null  object
#  13  multipleImage       16539 non-null  int64
#  14  NoOfImages          16539 non-null  int64
#  15  isVideo             16539 non-null  int64
#  16  localization        6887 non-null   object
#  17  tags                16539 non-null  object
#  18  numberLikes         16539 non-null  int64
#  19  url                 16539 non-null  object
#  20  Influencer Level    16539 non-null  object
#  21  description         16319 non-null  object
# dtypes: datetime64[ns](1), int64(7), object(14)
# memory usage: 2.8+ MB

# %% [markdown]
# **Engagement Rate**

# %%
train['engagement_rate']=100* (train.numberLikes/train.numberFollowers)

# %% [markdown]
# # Unique Labels

# %%
train.nunique()
# Out:
# numberPosts             881
# Website                 833
# urlProfile              973
# username                956
# numberFollowing         631
# descriptionProfile      939
# alias                   973
# numberFollowers         973
# urlImgProfile           973
# filename              16539
# Date                    337
# urlImage              16539
# mentions               9412
# multipleImage             2
# NoOfImages               10
# isVideo                   1
# localization           3327
# tags                   6469
# numberLikes           12233
# url                   16539
# Influencer Level          4
# description           15718
# engagement_rate       16506
# dtype: int64

# %%
ID_COL, TARGET_COL = 'filename', 'numberLikes'

# %% [markdown]
# # Target Distribution

# %%
_ = train[TARGET_COL].plot(kind = 'density', title = 'Likes Distribution', fontsize=14, figsize=(10, 6))

# %%
_ = train[TARGET_COL].plot(kind = 'box', vert=False, figsize=(12, 4), title = 'Likes Boxplot', fontsize=14)

# %% [markdown]
# **Obseravtions**
# 1. Highly right skewed data. Many outliers

# %% [markdown]
# # % NaN Values

# %%
null_values_per_variable = 100 * (train.isnull().sum()/train.shape[0]).round(3)#.reset_index()
null_values_per_variable.sort_values(ascending=False)
# Out:
# localization          58.4
# Website               11.4
# descriptionProfile     2.4
# description            1.3
# username               1.2
# engagement_rate        0.0
# filename               0.0
# urlProfile             0.0
# numberFollowing        0.0
# alias                  0.0
# numberFollowers        0.0
# urlImgProfile          0.0
# urlImage               0.0
# Date                   0.0
# mentions               0.0
# multipleImage          0.0
# NoOfImages             0.0
# isVideo                0.0
# tags                   0.0
# numberLikes            0.0
# url                    0.0
# Influencer Level       0.0
# numberPosts            0.0
# dtype: float64

# %%
train.isnull().sum()
# Out:
# numberPosts              0
# Website               1887
# urlProfile               0
# username               204
# numberFollowing          0
# descriptionProfile     391
# alias                    0
# numberFollowers          0
# urlImgProfile            0
# filename                 0
# Date                     0
# urlImage                 0
# mentions                 0
# multipleImage            0
# NoOfImages               0
# isVideo                  0
# localization          9652
# tags                     0
# numberLikes              0
# url                      0
# Influencer Level         0
# description            220
# engagement_rate          0
# dtype: int64

# %% [markdown]
# **Visually % of NaN**

# %%
plt.figure(figsize=(8,8))
sns.heatmap(train.isnull(),cmap='viridis',cbar=False,yticklabels=False)

# %% [markdown]
# **Obseravtions**
# 1. More than 50 % of data is missing for **localization**
# 2. **website** has also 11 % data missing

# %% [markdown]
# # Numerical and Categorical Variables

# %%
features = [c for c in train.columns if c not in [ID_COL, TARGET_COL]]
cat_cols = train.select_dtypes(include=['object'])
num_cols = train.select_dtypes(include=['int64'])


# categorical features
cat_cols = [c for c in features if c in cat_cols]

# numerical features
num_cols = [c for c in features if c in num_cols]

print('categorical variables')
display(cat_cols)
print('numerical variables')
display(num_cols)
# Out:
# categorical variables
# ['Website',
#  'urlProfile',
#  'username',
#  'descriptionProfile',
#  'alias',
#  'urlImgProfile',
#  'urlImage',
#  'mentions',
#  'localization',
#  'tags',
#  'url',
#  'Influencer Level',
#  'description']
# numerical variables
# ['numberPosts',
#  'numberFollowing',
#  'numberFollowers',
#  'multipleImage',
#  'NoOfImages',
#  'isVideo']

# %%
fig, axes = plt.subplots(7, 1, figsize=(10, 12))
for i, c in enumerate(num_cols):
  _ = train[[c]].boxplot(ax=axes[i], vert=False)

# %%
train.head()
# Out:
#    numberPosts                           Website  \
# 0           49  instagram.com/bestofstreetstyled
# 1           49  instagram.com/bestofstreetstyled
# 2           49  instagram.com/bestofstreetstyled
# 3           49  instagram.com/bestofstreetstyled
# 4           49  instagram.com/bestofstreetstyled
#
#                              urlProfile                       username  \
# 0  https://www.instagram.com/mensflair/  Men | Style | Class | Fashion
# 1  https://www.instagram.com/mensflair/  Men | Style | Class | Fashion
# 2  https://www.instagram.com/mensflair/  Men | Style | Class | Fashion
# 3  https://www.instagram.com/mensflair/  Men | Style | Class | Fashion
# 4  https://www.instagram.com/mensflair/  Men | Style | Class | Fashion
#
#    numberFollowing                                 descriptionProfile  \
# 0               10  Menswear & Lifestyle BE INSPIRED DAILY ____ Fo...
# 1               10  Menswear & Lifestyle BE INSPIRED DAILY ____ Fo...
# 2               10  Menswear & Lifestyle BE INSPIRED DAILY ____ Fo...
# 3               10  Menswear & Lifestyle BE INSPIRED DAILY ____ Fo...
# 4               10  Menswear & Lifestyle BE INSPIRED DAILY ____ Fo...
#
#        alias  numberFollowers  \
# 0  mensflair           124965
# 1  mensflair           124965
# 2  mensflair           124965
# 3  mensflair           124965
# 4  mensflair           124965
#
#                                        urlImgProfile  \
# 0  https://scontent.cdninstagram.com/t51.2885-19/...
# 1  https://scontent.cdninstagram.com/t51.2885-19/...
# 2  https://scontent.cdninstagram.com/t51.2885-19/...
# 3  https://scontent.cdninstagram.com/t51.2885-19/...
# 4  https://scontent.cdninstagram.com/t51.2885-19/...
#
#                                             filename  ... multipleImage  \
# 0  18161447_1658356384474317_9111601070664056832_...  ...             0
# 1  18298601_121409661745614_6986690297598050304_n...  ...             0
# 2  18161743_412774429107168_768065153252982784_n.jpg  ...             0
# 3  18251869_290881328035320_2327183756814712832_n...  ...             0
# 4  18160659_214392992395434_3720859060493352960_n...  ...             0
#
#   NoOfImages isVideo  localization  \
# 0          1       0           NaN
# 1          1       0           NaN
# 2          1       0           NaN
# 3          1       0           NaN
# 4          1       0           NaN
#
#                                                 tags  numberLikes  \
# 0  ['#suit', '#suits', '#gentlemen', '#gentlemens...           17
# 1                                                 []          304
# 2                                                 []          438
# 3  ['#suit', '#suits', '#gentlemen', '#gentlemens...          272
# 4                                                 []          672
#
#                                                  url Influencer Level  \
# 0  https://www.instagram.com/p/BTilZcThQq5/?taken...   Low Influencer
# 1  https://www.instagram.com/p/BTiROoghcLV/?taken...   Low Influencer
# 2  https://www.instagram.com/p/BTh66MZB7BP/?taken...   Low Influencer
# 3  https://www.instagram.com/p/BThniHNlXhO/?taken...   Low Influencer
# 4  https://www.instagram.com/p/BThRe9-BZh0/?taken...   Low Influencer
#
#                                          description engagement_rate
# 0  Courtesy of @the_vasco\r\n____________________...        0.013604
# 1  Style by: @johnnyedlind\r\nWhatcha say ï¿½ï¿½ï...        0.243268
# 2  Stunning View - Tag Someone You Would Skydive ...        0.350498
# 3  Courtesy of @magic_fox\r\n____________________...        0.217661
# 4  Tag someone you would take - Santorini, Greece...        0.537751
#
# [5 rows x 23 columns]

# %% [markdown]
# # Categorical Variables

# %%
cat_cols = ['isVideo', 'multipleImage','Influencer Level']
text_cols = ['username', 'descriptionProfile', 'alias','mentions','tags','description']

# %% [markdown]
# # Univariate Analysis (Numerical)

# %%
fig, axes = plt.subplots(1, 3, figsize=(60, 50))

for i, c in enumerate(cat_cols):
    _ = train[c].value_counts()[::-1].plot(kind = 'pie', ax=axes[i], title=c, autopct='%.0f', fontsize=18)
    _ = axes[i].set_ylabel('')
    
_ = plt.tight_layout()

# %% [markdown]
# **No. of likes of High influencers**

# %%
_ = sns.catplot(x="Influencer Level", y="numberLikes", data=train, height=5, aspect=24/8)

# %%
_ = sns.catplot(x="Influencer Level", y="engagement_rate", data=train, height=5, aspect=24/8)

# %%
_ = sns.catplot(x="Influencer Level", y="numberPosts", data=train, height=5, aspect=24/8)

# %% [markdown]
# **Top few usernames with maximum likes**

# %%
sns.set(rc={'figure.figsize':(12.7, 8.27)})

top_20_channels = train['username'].value_counts()[:10].reset_index()
top_20_channels.columns = ['username', 'numberLikes']

_ = sns.barplot(data = top_20_channels, y = 'username', x = 'numberLikes')
_ = plt.title("Top 10 UserNames with maximum number of likes")

# %% [markdown]
# **Top few mentions with maximum likes**

# %%
sns.set(rc={'figure.figsize':(12.7, 8.27)})

top_20_channels = train['mentions'].value_counts()[:3].reset_index()
top_20_channels.columns = ['mentions', 'numberLikes']

_ = sns.barplot(data = top_20_channels, y = 'mentions', x = 'numberLikes')
_ = plt.title("Top 3 mentions with maximum number of likes")

# %% [markdown]
# **Top few tags with maximum likes**

# %%
sns.set(rc={'figure.figsize':(12.7, 8.27)})

top_20_channels = train['tags'].value_counts()[:2].reset_index()
top_20_channels.columns = ['tags', 'numberLikes']

_ = sns.barplot(data = top_20_channels, y = 'tags', x = 'numberLikes')
_ = plt.title("Top 2 tags with maximum number of likes")

# %% [markdown]
# # Minimum and Maximum Date

# %%
train['Date'].min(), train['Date'].max()
# Out:
# (Timestamp('2013-06-09 00:00:00'), Timestamp('2017-12-04 00:00:00'))

# %% [markdown]
# # Yearwise Records

# %%
train['Date'].dt.year.value_counts()
# Out:
# 2017    16045
# 2016      456
# 2015       26
# 2014        7
# 2013        5
# Name: Date, dtype: int64

# %% [markdown]
# **Instagram posts in time series data from 2013-2017**

# %%
latest_data_train = train[train['Date'] > '2014']
_ = latest_data_train.sort_values(by = 'Date').groupby('Date').size().plot(figsize=(18, 6))

# %% [markdown]
# **Observation**
# 1. There is a sudden hike in Instagram posts in April-May , 2017
# 2. A huge plummet from May, 2017

# %%
latest_data_train = train[train['Date'] > '2017-3']
_ = latest_data_train.sort_values(by = 'Date').groupby('Date').size().plot(figsize=(18, 6))

# %% [markdown]
# # Mean Likes in data in 2017

# %%
latest_data = train[train['Date'] > '2017']
_ = latest_data.sort_values(by = 'Date').groupby('Date')['numberLikes'].mean().plot(figsize=(18, 6), title="Mean Likes on Instagram Posts")

# %% [markdown]
# # Word Clouds

# %%
from wordcloud import WordCloud, STOPWORDS

wc = WordCloud(stopwords = set(list(STOPWORDS) + ['|']), random_state = 42)
fig, axes = plt.subplots(3, 2, figsize=(20, 12))
axes = [ax for axes_row in axes for ax in axes_row]

for i, c in enumerate(text_cols):
  op = wc.generate(str(train[c]))
  _ = axes[i].imshow(op)
  _ = axes[i].set_title(c.upper(), fontsize=24)
  _ = axes[i].axis('off')

_ = fig.delaxes(axes[3])

# %% [markdown]
# # Extracting features from dates

# %%
for attr in ['year', 'month', 'day', 'week', 'dayofweek']:                                                                     # running loop for extracting new features from date
  train[attr] = getattr(train['Date'].dt, attr)

# %%
train.nunique()
# Out:
# numberPosts             881
# Website                 833
# urlProfile              973
# username                956
# numberFollowing         631
# descriptionProfile      939
# alias                   973
# numberFollowers         973
# urlImgProfile           973
# filename              16539
# Date                    337
# urlImage              16539
# mentions               9412
# multipleImage             2
# NoOfImages               10
# isVideo                   1
# localization           3327
# tags                   6469
# numberLikes           12233
# url                   16539
# Influencer Level          4
# description           15718
# engagement_rate       16506
# year                      5
# month                    12
# day                      31
# week                     51
# dayofweek                 7
# dtype: int64

# %% [markdown]
# **Did people posted more on Weekends instead of weekdays ?**

# %%
n_posts_per_day_of_week = train['dayofweek'].value_counts().sort_index().reset_index()
n_posts_per_day_of_week.columns = ['day_of_week', 'numberPosts']
n_posts_per_day_of_week['day_of_week'] = ['Mon', 'Tue', 'Wed', 'Thur', 'Fri', 'Sat', 'Sun']
_ = sns.catplot(x = 'day_of_week', y = 'numberPosts', data = n_posts_per_day_of_week, kind = 'point',aspect = 24/6)
_ = plt.title("Number of Posts Posted Per Day of Week", fontsize=20)

# %% [markdown]
# **Observations**
# 1. Posts on **Weekends** were more than normal week days

# %% [markdown]
# # Correlations

# %% [markdown]
# **Do descriptive posts get more number of likes or vice -versa ?**

# %%
train=train.dropna()

# %%
# Mentions
train['mentions_len'] = train['mentions'].apply(lambda x: len(x))
# Tags
train['tags_len'] = train['tags'].apply(lambda x: len(x))
# Description 
train['description_len'] = train['description'].apply(lambda x: len(x))
# Description Profile
train['description_profile_len'] = train['descriptionProfile'].apply(lambda x: len(x))

_  = sns.heatmap(train[['mentions_len', 'tags_len', 'description_len', 'description_profile_len','numberLikes']].corr(), annot = True)

# %%
plt.figure(figsize=(18, 8))
sns.heatmap(train.corr(),annot=True,cmap=plt.cm.CMRmap_r,linewidths=2)

# %%
train.drop('numberLikes', axis=1).corrwith(train.numberLikes).plot(kind='bar', grid=True, figsize=(12, 8), 
                                                   title="Correlation with Price")

# %% [markdown]
# **Observations**
# 1. Higher no. of followers have higher likes
# 2. May be higher likes are with theprofie with more posts
# 3. The longer the post description the less the likes
# 4. The more the Profile descritpion, the more the likes

# %%
train.columns
# Out:
# Index(['numberPosts', 'Website', 'urlProfile', 'username', 'numberFollowing',
#        'descriptionProfile', 'alias', 'numberFollowers', 'urlImgProfile',
#        'filename', 'Date', 'urlImage', 'mentions', 'multipleImage',
#        'NoOfImages', 'isVideo', 'localization', 'tags', 'numberLikes', 'url',
#        'Influencer Level', 'description', 'engagement_rate', 'year', 'month',
#        'day', 'week', 'dayofweek', 'mentions_len', 'tags_len',
#        'description_len', 'description_profile_len'],
#       dtype='object')
